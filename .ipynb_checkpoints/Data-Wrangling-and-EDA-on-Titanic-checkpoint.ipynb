# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Assessing
path = "C:\\Users\\HP\\OneDrive\\Desktop\\train.csv"
train = pd.read_csv(path)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
path = "C:\\Users\\HP\\OneDrive\\Desktop\\test.csv"
test =pd.read_csv(path)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#To check the total number of rows and columns in the data
train.shape
# Out:
# (891, 12)

# %%
# To check the lengh of the data. NOTE: length will only bring out the total numbers of rows only
train_length = len(train)

# %%
train_length
# Out:
# 891

# %%
#printing the first 10 rows in the data
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# printing the last 10 rows in the data
train.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# To check for 10 rows randomly
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 535          536         1       2
# 77            78         0       3
# 523          524         1       1
# 857          858         1       1
# 410          411         0       3
# 649          650         1       3
# 245          246         0       1
# 200          201         0       3
# 321          322         0       3
# 761          762         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 535                           Hart, Miss. Eva Miriam  female   7.0      0
# 77                          Moutal, Mr. Rahamin Haim    male   NaN      0
# 523  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 857                           Daly, Mr. Peter Denis     male  51.0      0
# 410                               Sdycoff, Mr. Todor    male   NaN      0
# 649                  Stanley, Miss. Amy Zillah Elsie  female  23.0      0
# ...

# %%
# TO combine the 2 datas(train and test together)
df =pd.concat([train,test],ignore_index = True)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# To detect for the total rows and coloum of the new combiled data 
df.shape
# Out:
# (1309, 12)

# %%
len(df)
# Out:
# 1309

# %%
# To summarize the dataFrame by knowing the infos in it
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
# To check for the statistical summary of the data
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
# To check for the missing values in the data
df.isna()
# Out:
#       PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  \
# 0           False     False   False  False  False  False  False  False
# 1           False     False   False  False  False  False  False  False
# 2           False     False   False  False  False  False  False  False
# 3           False     False   False  False  False  False  False  False
# 4           False     False   False  False  False  False  False  False
# ...           ...       ...     ...    ...    ...    ...    ...    ...
# 1304        False      True   False  False  False   True  False  False
# 1305        False      True   False  False  False  False  False  False
# 1306        False      True   False  False  False  False  False  False
# 1307        False      True   False  False  False   True  False  False
# 1308        False      True   False  False  False   True  False  False
#
#       Ticket   Fare  Cabin  Embarked
# 0      False  False   True     False
# 1      False  False  False     False
# ...

# %%
# To check for the summary of the missing value
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# To check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# To check for the data type of the dataframe
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Data Cleaning/data Wrangling

# %%
# To generate the mean of Age
ageMean = round(df["Age"].mean(),0)

# %%
ageMean
# Out:
# 30.0

# %%
# To temporarily fill the blank age rows with the age mean generated above
df["Age"].fillna(ageMean)
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304    30.0
# 1305    39.0
# 1306    38.5
# 1307    30.0
# 1308    30.0
# Name: Age, Length: 1309, dtype: float64

# %%
# You will notice the age blank space is still showing, 263 is NAN
df["Age"].isna().sum()
# Out:
# 263

# %%
# To permanently fill the blank age rows with the age mean generated 
df["Age"].fillna(ageMean, inplace = True)

# %%
df["Age"].isna().sum()
# Out:
# 0

# %%
# Taking care of the missing value in Fare
fare_mean = round(df['Fare'].mean(),0)

# %%
fare_mean
# Out:
# 33.0

# %%
df["Fare"].fillna(fare_mean, inplace = True)

# %%
df["Fare"].isna().sum()
# Out:
# 0

# %%
# TO drop the Cabin column from the data 
df.drop(columns = ["Cabin"], inplace = True)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
embarked_mode = df["Embarked"].mode(),[0]

# %%
embarked_mode
# Out:
# (0    S
#  Name: Embarked, dtype: object,
#  [0])

# %%
df["Embarked"].fillna('embarked_mode',inplace = True)

# Note that, because the data type is in text, the embarked mode has to be in quotation

# %%
df["Embarked"].isna().sum()
# Out:
# 0

# %%
# TO split the MR or Mrs Title from the Name column
title_split = lambda x:x.split()[1].strip(".")

# %%
# TO create a new column "Title" and using the splited title 
df["Title"] = df["Name"].apply(title_split)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df['Title'].value_counts()
# Out:
# Mr              736
# Miss            256
# Mrs             191
# Master           59
# Dr                8
# Rev               8
# y                 8
# Planke,           4
# Col               4
# Impe,             3
# Billiard,         3
# Mlle              2
# Carlo,            2
# Ms                2
# Major             2
# Gordon,           2
# Messemaeker,      2
# Velde,            1
# Palmquist,        1
# Khalil,           1
# Cruyssen,         1
# Melkebeke,        1
# Jonkheer          1
# Shawah,           1
# the               1
# Walle,            1
# Capt              1
# Don               1
# Pelsmaeker,       1
# Mme               1
# Steen,            1
# der               1
# Mulder,           1
# Brito,            1
# Name: Title, dtype: int64

# %%
title_list = ["Mr", "Miss","Mrs","Master","Dr","Rev"]

# %%
for title in df["Title"]:
    if title not in title_list:
        df["Title"].replace(title,"Mr",inplace= True)

# %%
df["Title"].value_counts()
# Out:
# Mr        787
# Miss      256
# Mrs       191
# Master     59
# Rev         8
# Dr          8
# Name: Title, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Unit Variante Analysis - comparing just a column
count_class = df["Pclass"].value_counts()

# %%
count_class
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
count_class.index= ["Third","First","Second"]

# %%
count_class
# Out:
# Third     709
# First     323
# Second    277
# Name: Pclass, dtype: int64

# %%
count_class.plot(kind = "bar", color= "black")
plt.title("Count of Class")
plt.xlabel("Class count")
plt.ylabel("Count")
plt.xticks(rotation = 35, color = "blue")
plt.xticks(rotation = 35, color = "green")
plt.show()

# %%
count_Sex = df["Sex"].value_counts()

# %%
count_Sex
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
count_Sex.plot(kind = "bar", color = 'black')
plt.title("Gender count")
plt.xlabel("Count of sex")
plt.ylabel("Count")
plt.xticks(rotation = 30, color= "green")
plt.yticks(rotation = 30, color = "blue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
count_Sex.plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
# To find the types or kinds of plot
help(pd.DataFrame.plot)
# Out:
# Help on class PlotAccessor in module pandas.plotting._core:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
# Bi Variante Analysis - comparing more than 1 column
dead = df.query("Survived ==0")["Pclass"].value_counts()
alive = df.query("Survived == 1")["Pclass"].value_counts()

# %%
dead
# Out:
# 3    372
# 2     97
# 1     80
# Name: Pclass, dtype: int64

# %%
alive
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
survivedStatus = pd.concat([dead,alive],axis = 1, keys=["dead","alive"])

# %%
survivedStatus
# Out:
#    dead  alive
# 3   372    119
# 2    97     87
# 1    80    136

# %%
survivedStatus.plot(kind="bar")
plt.title("Survival Status")
plt.xlabel("Count of Survivals")
plt.ylabel("Count")
plt.xticks(rotation = 30, color= "green")
plt.yticks(rotation = 30, color = "blue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(data =df,x=("Pclass"),y=("Age"))
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
# Research  or write about outliers, when to use it ad how to inteprete an outliers
